# %% [markdown]
# ## Researching a business name for an entrepreneur

# %% [markdown]
# #### An entrepreneur in New Orleans Louisiana would like to open a business in the French Quarter and would like to know if 'Cajun' is an overused name for the business.

# %% [markdown]
# #### The Business would be based within 1km of the Ritz Carleton Hotel, 921 Canal Street.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          92 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#
#
#
# ...
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# ...

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# ##### Make sure that you have created a Foursquare developer account and have your credentials handy

# %%
CLIENT_ID = 'R5ACXU4DWICEJYRTMLSENEKWOY5WZGOIHILBPHNSRC4BGFQS' # your Foursquare ID
CLIENT_SECRET = 'FU1BCCQHVP00GJCZZAVP0G3NV2BIPOEALW3UHR5VVGV1RYKR' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: R5ACXU4DWICEJYRTMLSENEKWOY5WZGOIHILBPHNSRC4BGFQS
# CLIENT_SECRET:FU1BCCQHVP00GJCZZAVP0G3NV2BIPOEALW3UHR5VVGV1RYKR

# %%
address = '921 Canal Street, New Orleans, LA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 29.9552319 -90.0707928

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ## 1. Search for a specific venue category
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %%
search_query = 'Cajun'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Cajun .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=R5ACXU4DWICEJYRTMLSENEKWOY5WZGOIHILBPHNSRC4BGFQS&client_secret=FU1BCCQHVP00GJCZZAVP0G3NV2BIPOEALW3UHR5VVGV1RYKR&ll=29.9552319,-90.0707928&v=20180604&query=Cajun&radius=1000&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9d6cd769babe001bcca8fd'},
#  'response': {'venues': [{'id': '41326e00f964a52089181fe3',
#     'name': "Cajun Mikes Pub 'n Grub",
#     'location': {'address': '116 Baronne St',
#      'crossStreet': 'btw Canal & Common',
#      'lat': 29.954042926325744,
#      'lng': -90.0713216326432,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.954042926325744,
#        'lng': -90.0713216326432},
#       {'label': 'entrance', 'lat': 29.954093, 'lng': -90.071087}],
#      'distance': 141,
#      'postalCode': '70112',
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['116 Baronne St (btw Canal & Common)',
#       'New Orleans, LA 70112',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
# ...

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                         name  \
# 0  41326e00f964a52089181fe3      Cajun Mikes Pub 'n Grub
# 1  4c9b77b5eaa5a1436721d5e4  Cajun Encounters Swamp Tour
# 2  4c261aa9f1272d7f70e085c5       Cajun Encounters Tours
# 3  50155e1de4b0bc7cf5e39684         Cajun Flavor Country
# 4  4dc4101dfa76d685cdbca4aa                 Cajun Corner
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d116941735', 'name': 'B...  v-1587375412    False
# 1  [{'id': '56aa371be4b08b9a8d573520', 'name': 'T...  v-1587375412    False
# 2  [{'id': '4f4530164b9074f6e4fb00ff', 'name': 'T...  v-1587375412    False
# 3  [{'id': '4bf58dd8d48988d15a941735', 'name': 'G...  v-1587375412    False
# ...

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                       name                  categories  \
# 0                  Cajun Mikes Pub 'n Grub                         Bar
# 1              Cajun Encounters Swamp Tour               Tour Provider
# 2                   Cajun Encounters Tours  Tourist Information Center
# 3                     Cajun Flavor Country                      Garden
# 4                             Cajun Corner   Cajun / Creole Restaurant
# 5           Jazz Gumbo Cajun Country Store           Convenience Store
# 6           Gumbo Yaya Cajun Country Store                   Gift Shop
# 7                           Cajun Bicycles    Bike Rental / Bike Share
# 8                              Cajun Swamp                   Gift Shop
# 9              Cajun Encounters City Tours       General Entertainment
# 10                           Cajun Country            Department Store
# 11                  Kosher Cajun @ #NOLAGA                        None
# ...

# %% [markdown]
# #### Let's visualize the Cajun businesses that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                    Cajun Mikes Pub 'n Grub
# 1                Cajun Encounters Swamp Tour
# 2                     Cajun Encounters Tours
# 3                       Cajun Flavor Country
# 4                               Cajun Corner
# 5             Jazz Gumbo Cajun Country Store
# 6             Gumbo Yaya Cajun Country Store
# 7                             Cajun Bicycles
# 8                                Cajun Swamp
# 9                Cajun Encounters City Tours
# 10                             Cajun Country
# 11                    Kosher Cajun @ #NOLAGA
# 12                                 Cajun AFC
# 13                  Zydeco Blues Cajun Store
# 14                Chevron Cajun Zydeco Stage
# 15                  Cajun Encounters- Garage
# 16                        Cajun Clothing Co.
# 17                           Cajun Mini Mart
# 18             Cajun Encounters Tour Company
# 19                             Cajun Cookery
# 20    Harrah's Cajun zydeco Stage Riverfront
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the hotel

# add a red circle marker to represent the Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Cajun restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 2. Attempt #2, Try "Acadian"
# > `https://api.foursquare.com/v2/venues/`**search**`?client_id=`**CLIENT_ID**`&client_secret=`**CLIENT_SECRET**`&ll=`**LATITUDE**`,`**LONGITUDE**`&v=`**VERSION**`&query=`**QUERY**`&radius=`**RADIUS**`&limit=`**LIMIT**

# %%
search_query = 'Acadian'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Acadian .... OK!

# %% [markdown]
# #### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=R5ACXU4DWICEJYRTMLSENEKWOY5WZGOIHILBPHNSRC4BGFQS&client_secret=FU1BCCQHVP00GJCZZAVP0G3NV2BIPOEALW3UHR5VVGV1RYKR&ll=29.9552319,-90.0707928&v=20180604&query=Acadian&radius=1000&limit=30'

# %% [markdown]
# #### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9d6e490f596800261b1f23'},
#  'response': {'venues': [{'id': '5188fd2b498ee42627a9ce97',
#     'name': 'Acadian Room',
#     'location': {'lat': 29.950374016398,
#      'lng': -90.06976564204646,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 29.950374016398,
#        'lng': -90.06976564204646}],
#      'distance': 549,
#      'cc': 'US',
#      'city': 'New Orleans',
#      'state': 'LA',
#      'country': 'United States',
#      'formattedAddress': ['New Orleans, LA', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d171941735',
#       'name': 'Event Space',
#       'pluralName': 'Event Spaces',
#       'shortName': 'Event Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/eventspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587375871',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id          name  \
# 0  5188fd2b498ee42627a9ce97  Acadian Room
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d171941735', 'name': 'E...  v-1587375871    False
#
#    location.lat  location.lng  \
# 0     29.950374    -90.069766
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 29.950374016398, ...                549
#
#   location.cc location.city location.state location.country  \
# 0          US   New Orleans             LA    United States
#
#           location.formattedAddress
# 0  [New Orleans, LA, United States]

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                       name                  categories  \
# 0                  Cajun Mikes Pub 'n Grub                         Bar
# 1              Cajun Encounters Swamp Tour               Tour Provider
# 2                   Cajun Encounters Tours  Tourist Information Center
# 3                     Cajun Flavor Country                      Garden
# 4                             Cajun Corner   Cajun / Creole Restaurant
# 5           Jazz Gumbo Cajun Country Store           Convenience Store
# 6           Gumbo Yaya Cajun Country Store                   Gift Shop
# 7                           Cajun Bicycles    Bike Rental / Bike Share
# 8                              Cajun Swamp                   Gift Shop
# 9              Cajun Encounters City Tours       General Entertainment
# 10                           Cajun Country            Department Store
# 11                  Kosher Cajun @ #NOLAGA                        None
# ...

# %% [markdown]
# #### Let's visualize the Cajun businesses that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                    Cajun Mikes Pub 'n Grub
# 1                Cajun Encounters Swamp Tour
# 2                     Cajun Encounters Tours
# 3                       Cajun Flavor Country
# 4                               Cajun Corner
# 5             Jazz Gumbo Cajun Country Store
# 6             Gumbo Yaya Cajun Country Store
# 7                             Cajun Bicycles
# 8                                Cajun Swamp
# 9                Cajun Encounters City Tours
# 10                             Cajun Country
# 11                    Kosher Cajun @ #NOLAGA
# 12                                 Cajun AFC
# 13                  Zydeco Blues Cajun Store
# 14                Chevron Cajun Zydeco Stage
# 15                  Cajun Encounters- Garage
# 16                        Cajun Clothing Co.
# 17                           Cajun Mini Mart
# 18             Cajun Encounters Tour Company
# 19                             Cajun Cookery
# 20    Harrah's Cajun zydeco Stage Riverfront
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the hotel

# add a red circle marker to represent the Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Cajun restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <a id="item2"></a>

# %% [markdown]
# <a id="item2"></a>
